# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
list_post_x = [0.14285714, 0.92857143, 0.82142857, 0.89285714, 0.21428571,  0.28571429, 0.35714286, 0.42857143,
               0.5, 0.64285714, 0.78571429,  0.85714286,  0.92857143, 0.25, 0.32142857, 0.39285714, 0.46428571,
               0.53571428, 0.60714286, 0.67857143, 0.75, 0.82142857, 0.89285714, 0.21428571, 0.28571429, 0.35714286,
               0.42857143, 0.5, 0.57142857, 0.64285714, 0.71428571, 0.78571429, 0.25, 0.32142857, 0.39285714, 0.46428571,
               0.53571428,  0.60714286,  0.67857143, 0.75, 0.96428571, 0.35714286,  0.42857143,  0.5,  0.57142857,
               0.64285714, 0.71428571, 0.39285714, 0.67857143, 0.14285714, 0.71428571]

# %%
list_post_y = [0.750,0.750,0.6875,0.6875,0.625,0.625,0.625,0.625,0.625,0.625,0.625,0.625,0.625,
               0.5625,0.5625,0.5625,0.5625,0.5625,0.5625,0.5625,0.5625,0.5625,0.5625,0.500,0.500,0.500,
               0.500,0.500,0.500,0.500,0.500,0.500,0.4375,0.4375,0.4375,0.4375,0.4375,0.4375,0.4375,
               0.4375,0.4375,0.375,0.375,0.375,0.375,0.375,0.375,0.3125,0.3125,0.250,0.250]

# %%
x = np.array(list_post_x)
y = np.array(list_post_y)

# %%
state_labels = ['AK','ME','VT','NH','WA','MT','ND','MN','WI','MI','NY','MA','RI','ID','WY','SD','IA','IL','IN','OH','PA',
               'NJ','CT','OR','NV','CO','NE','MO','KY','WV','MD','DE','CA','AZ','UT','KS','AR','TN','VA','NC','DC','NM','OK',
                'LA','MS','AL','SC','TX','GA','HI','FL']

# %%
plt.figure(figsize=(16.9,11.375))
plt.scatter(x,y,marker="h", s=5000, color='blue')
plt.xticks(np.linspace(0, 1, num=15))
plt.yticks(np.linspace(0, 1, num=17))
plt.grid(color='blue', linestyle='-', linewidth=2)
for i in range(0,51):
    plt.text(list_post_x[i], list_post_y[i],state_labels[i],ha='center',va='center',size=18, color='white', weight='bold')
plt.xlim(0.07142857,1)
plt.ylim(0.1875,0.8125)
plt.show()
